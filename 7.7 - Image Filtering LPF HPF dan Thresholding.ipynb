# %% [markdown]
# ## Image Filtering

# %% [markdown]
# **1. Low-Pass Filtering**

# %%
import cv2  # Mengimpor library OpenCV
import numpy as np  # Mengimpor library NumPy untuk operasi matriks
from matplotlib import pyplot as plt  # Mengimpor library Matplotlib untuk visualisasi

# Baca citra awal
img = cv2.imread('Image/zee.jpeg')  # Membaca citra dengan nama file 'zee.jpeg' menggunakan OpenCV

# Ubah ke format RGB
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Mengubah format citra dari BGR (default OpenCV) ke RGB

# Membuat filter: matriks berukuran 5 x 5 dengan nilai setiap elemen adalah 1/25
kernel = np.ones((3, 3), np.float32) / 25

# Melakukan filtering
zee_filter = cv2.filter2D(img, -1, kernel)  # Melakukan filtering pada citra menggunakan filter kernel

# %%
kernel = np.ones((3, 3), np.float32) / 25
# Membuat kernel berukuran 3 x 3 dengan setiap elemennya bernilai 1/25. Digunakan untuk filtering rata-rata.

zee_filter = cv2.filter2D(img, -1, kernel)
# Melakukan filtering pada citra 'img' menggunakan kernel 'kernel'. Hasil filtering disimpan dalam 'zee_filter'.

plt.rcParams["figure.figsize"] = (10, 10)
# Mengatur ukuran tampilan plot menjadi 10x10 inch.

plt.subplot(121)
# Membuat subplot dengan 1 baris, 2 kolom, dan mengambil posisi pertama (1).

plt.imshow(img)
# Menampilkan citra asli.

plt.title('Original')
# Memberikan judul pada subplot.

plt.xticks([])
plt.yticks([])
# Menghilangkan label sumbu x dan y.

plt.subplot(122)
# Membuat subplot dengan 1 baris, 2 kolom, dan mengambil posisi kedua (2).

plt.imshow(zee_filter)
# Menampilkan hasil filtering.

plt.title('Averaging')
# Memberikan judul pada subplot.

plt.xticks([])
plt.yticks([])
# Menghilangkan label sumbu x dan y.
# Out:
# ([], [])

# %%
zee_blur = cv2.blur(img, (5, 5))
# Melakukan proses blurring pada citra 'img' menggunakan filter berukuran 5x5. Hasil blurring disimpan dalam 'zee_blur'.

plt.rcParams["figure.figsize"] = (10, 5)
# Mengatur ukuran tampilan plot menjadi 10x5 inch.

plt.subplot(221)
# Membuat subplot dengan 2 baris, 2 kolom, dan mengambil posisi pertama (1).

plt.imshow(img, cmap='gray')
# Menampilkan citra asli dengan menggunakan colormap 'gray'.

plt.title('Original')
# Memberikan judul pada subplot.

plt.xticks([])
plt.yticks([])
# Menghilangkan label sumbu x dan y.

plt.subplot(222)
# Membuat subplot dengan 2 baris, 2 kolom, dan mengambil posisi kedua (2).

plt.imshow(zee_blur, cmap='gray')
# Menampilkan citra hasil blurring dengan menggunakan colormap 'gray'.

plt.title('Gambar Blur')
# Memberikan judul pada subplot.

plt.xticks([])
plt.yticks([])
# Menghilangkan label sumbu x dan y.

plt.subplot(223)
# Membuat subplot dengan 2 baris, 2 kolom, dan mengambil posisi ketiga (3).

plt.hist(img.ravel(), 256, [0, 256], color='blue', alpha=0.7)
# Menampilkan histogram dari citra asli.

plt.title('Histogram Citra Asli')
# Memberikan judul pada subplot.

plt.xlabel('Intensitas Piksel')
plt.ylabel('Frekuensi')
# Memberikan label sumbu x dan y.

plt.subplot(224)
# Membuat subplot dengan 2 baris, 2 kolom, dan mengambil posisi keempat (4).

plt.hist(zee_blur.ravel(), 256, [0, 256], color='green', alpha=0.7)
# Menampilkan histogram dari citra hasil blurring.

plt.title('Histogram Citra Setelah Blur')
# Memberikan judul pada subplot.

plt.xlabel('Intensitas Piksel')
plt.ylabel('Frekuensi')
# Memberikan label sumbu x dan y.

plt.tight_layout()
# Menyusun tata letak subplot secara otomatis.

plt.show()
# Menampilkan plot.

# %%
# ini adalah cara lain untuk membuat sebuah kernel, 
# yaitu dengan menggunakan np.matrix
# kali ini, ukuran matriksnya 3 x 3
# Membuat kernel
kernel = np.matrix([
          [1, 1, 1],
          [1, 2, 1],
          [1, 1, 1]         
          ])/25
# Membuat kernel dengan menggunakan np.matrix. Kernel ini berukuran 3x3 dan memiliki nilai tertentu yang digunakan untuk proses filtering.

# Melakukan filtering
zee_filter = cv2.filter2D(img, -1, kernel)
# Melakukan proses filtering pada citra 'img' menggunakan kernel yang telah dibuat. Hasil filtering disimpan dalam variabel 'zee_filter'.

# Membuat plot
fig, axs = plt.subplots(2, 2, figsize=(10, 5))
# Membuat sebuah figure dengan 2 baris dan 2 kolom, dengan ukuran 10x5 inch. Akan terdiri dari 4 plot.

# Plot gambar asli
axs[0, 0].imshow(img, cmap='gray')
axs[0, 0].set_title('Original')
axs[0, 0].axis('off')
# Menampilkan citra asli pada subplot pertama. Memberikan judul 'Original' pada subplot. Menghilangkan sumbu x dan y pada subplot.

# Plot hasil filtering
axs[0, 1].imshow(zee_filter, cmap='gray')
axs[0, 1].set_title('Averaging')
axs[0, 1].axis('off')
# Menampilkan citra hasil filtering pada subplot kedua. Memberikan judul 'Averaging' pada subplot. Menghilangkan sumbu x dan y pada subplot.

# Plot histogram citra asli
axs[1, 0].hist(img.ravel(), 256, [0, 256], color='blue', alpha=0.7)
axs[1, 0].set_title('Histogram Citra Asli')
axs[1, 0].set_xlabel('Intensitas Piksel')
axs[1, 0].set_ylabel('Frekuensi')
# Menampilkan histogram dari citra asli pada subplot ketiga. Memberikan judul 'Histogram Citra Asli' pada subplot. Memberikan label sumbu x dan y pada subplot.

# Plot histogram citra setelah filtering
axs[1, 1].hist(zee_filter.ravel(), 256, [0, 256], color='green', alpha=0.7)
axs[1, 1].set_title('Histogram Citra Setelah Filtering')
axs[1, 1].set_xlabel('Intensitas Piksel')
axs[1, 1].set_ylabel('Frekuensi')
# Menampilkan histogram dari citra hasil filtering pada subplot keempat. Memberikan judul 'Histogram Citra Setelah Filtering' pada subplot. Memberikan label sumbu x dan y pada subplot.

plt.tight_layout()
# Menyusun tata letak subplot secara otomatis agar lebih rapi.

# %% [markdown]
# **2. High-Pass Filtering**

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Baca citra awal
img = cv2.imread('Image/Ronaldo.jpeg', 0)

# Menerapkan algoritma high-pass filtering:
# Laplacian
laplacian = cv2.Laplacian(img, cv2.CV_64F)

# Sobel dengan ukuran kernel 5
sobelx = cv2.Sobel(img, cv2.CV_64F, 1, 0, ksize=5)
sobely = cv2.Sobel(img, cv2.CV_64F, 0, 1, ksize=5)

# Perbesar ukuran hasil plotting
plt.rcParams["figure.figsize"] = (10, 5)

# Menampilkan hasil filter
plt.subplot(2, 2, 1), plt.imshow(img, cmap='gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2, 2, 2), plt.imshow(laplacian, cmap='gray')
plt.title('Laplacian'), plt.xticks([]), plt.yticks([])
plt.subplot(2, 2, 3), plt.imshow(sobelx, cmap='gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])
plt.subplot(2, 2, 4), plt.imshow(sobely, cmap='gray')
plt.title('Sobel Y'), plt.xticks([]), plt.yticks([])

# Membuat histogram dalam satu plot
plt.figure()
plt.subplot(2, 2, 1)
plt.hist(img.ravel(), 256, [0, 256])
plt.title('Histogram - Original')
plt.subplot(2, 2, 2)
plt.hist(laplacian.ravel(), 256, [0, 256])
plt.title('Histogram - Laplacian')
# Out:
# Text(0.5, 1.0, 'Histogram - Laplacian')

# %%
# Memanggil citra sebagai grayscale (argument 0)
img = cv2.imread('Image/Ronaldo.jpeg', 0)
# Membaca citra 'Ronaldo.jpeg' dalam format grayscale menggunakan fungsi imread dari OpenCV. Hasilnya disimpan dalam variabel 'img'.

# Memanggil fungsi Canny Edges dengan argument (citra, nilai_min, nilai_max)
edges = cv2.Canny(img, 100, 200)
# Menerapkan deteksi tepi menggunakan metode Canny pada citra 'img' dengan nilai threshold minimum 100 dan threshold maksimum 200. Hasilnya disimpan dalam variabel 'edges'.

# Perbesar ukuran hasil plotting
plt.rcParams["figure.figsize"] = (13, 6)
# Mengatur ukuran gambar hasil plotting agar lebih besar dengan mengubah nilai default 'figure.figsize' menggunakan plt.rcParams.

# Menampilkan citra asli dan citra tepi dalam satu plot
plt.subplot(2, 2, 1), plt.imshow(img, cmap='gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(2, 2, 2), plt.imshow(edges, cmap='gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
# Membuat subplot dengan 2 baris dan 2 kolom. Pada subplot pertama, menampilkan citra asli dengan judul 'Original Image'. Pada subplot kedua, menampilkan citra tepi dengan judul 'Edge Image'.

# Menampilkan histogram citra asli
plt.subplot(2, 2, 3)
plt.hist(img.ravel(), bins=256, color='red')
plt.title('Histogram - Original Image')
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')
# Membuat subplot untuk menampilkan histogram dari citra asli. Memberikan judul 'Histogram - Original Image'. Memberikan label sumbu x dan y pada subplot.

# Menampilkan histogram citra sesudah filtering
plt.subplot(2, 2, 4)
plt.hist(edges.ravel(), bins=256, color='red')
plt.title('Histogram - Edge Image')
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')
# Membuat subplot untuk menampilkan histogram dari citra tepi. Memberikan judul 'Histogram - Edge Image'. Memberikan label sumbu x dan y pada subplot.
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ## Image Thresholding

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# membaca gambar
img = cv2.imread('Image/cris.jpg', 0)
# Membaca gambar 'cris.jpg' dalam format grayscale menggunakan fungsi imread dari OpenCV. Hasilnya disimpan dalam variabel 'img'.

# Hitungan threshold.
# Perhatikan nilai ambang batas bawah dan atas dari tiap fungsi yang diberikan
ret, thresh1 = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)
ret, thresh2 = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY_INV)
ret, thresh3 = cv2.threshold(img, 127, 255, cv2.THRESH_TRUNC)
ret, thresh4 = cv2.threshold(img, 127, 255, cv2.THRESH_TOZERO)
ret, thresh5 = cv2.threshold(img, 127, 255, cv2.THRESH_TOZERO_INV)
# Menggunakan fungsi thresholding dari OpenCV untuk menghasilkan citra biner dengan menggunakan nilai threshold 127. Hasilnya disimpan dalam variabel-variabel 'thresh1' hingga 'thresh5'.

# menampilkan hasil
titles = ['Gambar asli', 'BINARY', 'BINARY_INV', 'TRUNC', 'TOZERO', 'TOZERO_INV']
images = [img, thresh1, thresh2, thresh3, thresh4, thresh5]
# Membuat list judul 'titles' yang akan digunakan untuk memberikan judul pada setiap gambar yang akan ditampilkan. Membuat list 'images' yang berisi citra asli dan hasil thresholding.

# menampilkan beberapa gambar sekaligus
for i in range(6):
    # 3 baris, 2 kolom
    plt.subplot(3, 2, i + 1), plt.imshow(images[i], 'gray')
    plt.title(titles[i])
    plt.xticks([]), plt.yticks([])
# Melakukan iterasi untuk menampilkan gambar-gambar secara berurutan. Mengatur tata letak subplot dengan 3 baris dan 2 kolom. Menampilkan gambar pada subplot yang sesuai, memberikan judul menggunakan 'titles', dan menghilangkan label sumbu x dan y.

plt.tight_layout()
plt.show()
# Mengatur tata letak subplot agar lebih rapi dan menampilkan plot.

# Membuat histogram dari gambar asli
plt.subplot(2, 3, 1)
plt.hist(img.ravel(), 256, [0, 256])
plt.title('Histogram Gambar asli')
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')
# Membuat subplot untuk menampilkan histogram dari citra asli. Menampilkan histogram menggunakan fungsi hist dari matplotlib. Memberikan judul, label sumbu x, dan sumbu y pada subplot.

# Membuat histogram dari gambar setelah di filter
for i in range(1, 6):
    plt.subplot(2, 3, i + 1)
    plt.hist(images[i].ravel(), 256, [0, 256])
    plt.title('Histogram ' + titles[i])
    plt.xlabel('Pixel Value')
    plt.ylabel('Frequency')
# Melakukan iterasi untuk menampilkan histogram dari gambar hasil thresholding. Mengatur tata letak subplot dengan 2 baris dan 3 kolom. Menampilkan histogram menggunakan fungsi hist dari matplotlib. Memberikan judul, label sumbu x, dan sumbu y pada subplot.

plt.tight_layout()
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# membaca gambar
img = cv2.imread('Image/cris.jpg', 0)
# Membaca gambar 'cris.jpg' dalam format grayscale menggunakan fungsi imread dari OpenCV. Hasilnya disimpan dalam variabel 'img'.

# digunakan median blur untuk menghaluskan tepi objek pada citra
# ini diperlukan agar thresholding memberikan hasil lebih baik
img = cv2.medianBlur(img, 5)
# Menggunakan median blur dari OpenCV untuk menghaluskan tepi objek pada citra sebelum dilakukan thresholding. Hal ini membantu menghasilkan thresholding yang lebih baik.

# Lakukan Thresholding
# Binary Threshold
ret, th1 = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)
# Melakukan thresholding binary menggunakan fungsi threshold dari OpenCV dengan nilai threshold 127.

# Adaptive Threshold dengan Mean
th2 = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 11, 2)
# Melakukan thresholding adaptif dengan metode mean menggunakan fungsi adaptiveThreshold dari OpenCV. Menggunakan ukuran blok 11x11 dan konstanta C sebesar 2.

# Adaptive Threshold dengan Gaussian
th3 = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 11, 2)
# Melakukan thresholding adaptif dengan metode Gaussian menggunakan fungsi adaptiveThreshold dari OpenCV. Menggunakan ukuran blok 11x11 dan konstanta C sebesar 2.

# Plotting
titles = ['Original Image', 'Global Thresholding (v = 127)', 'Adaptive Mean Thresholding', 'Adaptive Gaussian Thresholding']
images = [img, th1, th2, th3]
# Membuat list judul 'titles' yang akan digunakan untuk memberikan judul pada setiap gambar yang akan ditampilkan. Membuat list 'images' yang berisi citra asli dan hasil thresholding.

# menampilkan hasil
for i in range(4):
    plt.subplot(2, 2, i + 1)
    plt.imshow(images[i], 'gray')
    plt.title(titles[i])
    plt.xticks([]), plt.yticks([])
# Melakukan iterasi untuk menampilkan gambar-gambar secara berurutan. Mengatur tata letak subplot dengan 2 baris dan 2 kolom. Menampilkan gambar pada subplot yang sesuai, memberikan judul menggunakan 'titles', dan menghilangkan label sumbu x dan y.

plt.tight_layout()
plt.show()
# Mengatur tata letak subplot agar lebih rapi dan menampilkan plot.

# Membuat histogram dari gambar asli
plt.subplot(2, 2, 1)
plt.hist(img.ravel(), 256, [0, 256])
plt.title('Histogram Gambar asli')
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')

# Membuat histogram dari gambar setelah di filter
for i in range(1, 4):
    plt.subplot(2, 2, i + 1)
    plt.hist(images[i].ravel(), 256, [0, 256])
    plt.title('Histogram ' + titles[i])
    plt.xlabel('Pixel Value')
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()
#
